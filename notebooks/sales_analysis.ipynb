# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/sales_data.csv')
df.head()
# Out:
#    order_id  order_date customer_id     product     category  quantity  price  \
# 0         1  2024-01-05        C101      Laptop  Electronics         1  60000
# 1         2  2024-01-07        C102      Mobile  Electronics         2  20000
# 2         3  2024-02-10        C103       Shoes      Fashion         3   3000
# 3         4  2024-02-15        C104     T-shirt      Fashion         5   1000
# 4         5  2024-03-01        C105  Headphones  Electronics         2   2500
#
#   region payment_method
# 0  North           Card
# 1  South            UPI
# 2   West            COD
# 3   East           Card
# 4  North            UPI

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['revenue'] = df['quantity'] * df['price']
df.head()
# Out:
#    order_id order_date customer_id     product     category  quantity  price  \
# 0         1 2024-01-05        C101      Laptop  Electronics         1  60000
# 1         2 2024-01-07        C102      Mobile  Electronics         2  20000
# 2         3 2024-02-10        C103       Shoes      Fashion         3   3000
# 3         4 2024-02-15        C104     T-shirt      Fashion         5   1000
# 4         5 2024-03-01        C105  Headphones  Electronics         2   2500
#
#   region payment_method  revenue
# 0  North           Card    60000
# 1  South            UPI    40000
# 2   West            COD     9000
# 3   East           Card     5000
# 4  North            UPI     5000

# %%
monthly_sales = df.groupby(df['order_date'].dt.month)['revenue'].sum()

plt.figure()
monthly_sales.plot()
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
region_sales = df.groupby('region')['revenue'].sum().reset_index()

plt.figure()
sns.barplot(x='region', y='revenue', data=region_sales)
plt.title("Revenue by Region")
plt.show()
